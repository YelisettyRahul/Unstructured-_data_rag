# %%
# Install libraries
# !pip install langchain-community unstructured langchain-openai openai faiss-cpu
# Out:
# ...
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      -------------------------------------- 981.5/981.5 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 4.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/590.6 kB ? eta -:--:--
#    ---------------------------------------- 590.6/590.6 kB 4.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------------- -------------------- 0.8/1.6 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 3.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
# ...

# %%
# !pip show langchain
# !pip show langchain-openai
# !pip show unstructured
# Out:
# Name: langchain
# Version: 0.3.19
# Summary: Building applications with LLMs through composability
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\Yelisetty rahul\anaconda3\Lib\site-packages
# Requires: aiohttp, langchain-core, langchain-text-splitters, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by: langchain-community
# Name: langchain-openai
# Version: 0.3.6
# Summary: An integration package connecting OpenAI and LangChain
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\Yelisetty rahul\anaconda3\Lib\site-packages
# Requires: langchain-core, openai, tiktoken
# Required-by:
# Name: unstructured
# Version: 0.16.23
# Summary: A library that prepares raw documents for downstream ML tasks.
# Home-page: https://github.com/Unstructured-IO/unstructured
# Author: Unstructured Technologies
# Author-email: devops@unstructuredai.io
# License: Apache-2.0
# ...

# %%
# Import functions / modules
from langchain_community.document_loaders import UnstructuredExcelLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.vectorstores.faiss import FAISS
from IPython.display import display, Markdown

# %%
OneDrive/SEB JECTS/langchain/unstructured_data/Reviews.xlsx

# %%
# Load the excel data
# Use UnstructuredExcelLoader to parse the data into individual components
loader = UnstructuredExcelLoader("unstructured_data/Reviews.xlsx", mode = "elements")
docs = loader.load() # Load the data from the Excel file into `docs`

# Display the first 5 elements
docs[:5]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Load the excel data
#       2 # Use UnstructuredExcelLoader to parse the data into individual components
#       3 loader = UnstructuredExcelLoader("unstructured_data/Reviews.xlsx", mode = "elements")
# ----> 4 docs = loader.load() # Load the data from the Excel file into `docs`
#       6 # Display the first 5 elements
#       7 docs[:5]
#
# File ~\anaconda3\Lib\site-packages\langchain_core\document_loaders\base.py:31, in BaseLoader.load(self)
#      29 def load(self) -> list[Document]:
#      30     """Load data into Document objects."""
# ---> 31     return list(self.lazy_load())
#
# File ~\anaconda3\Lib\site-packages\langchain_community\document_loaders\unstructured.py:107, in UnstructuredBaseLoader.lazy_load(self)
#     105 def lazy_load(self) -> Iterator[Document]:
# ...
